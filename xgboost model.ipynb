# %% [markdown]
# ### Data Engineer Assignment

# %% [markdown]
# ### Task
# Your colleagues from data science team have developed a prediction model with the following scripts in this notebook, now they need you to help them to <b> put this model in production </b>. In specific, the model should run on a new set of subscribers every Tuesday at 8am, and its output will be delivered to stakeholders and used in the campaigns.
#
#
# ### Sub-tasks
# 1. Create a weekly scheduled job that uses the model to predict whether a subscriber with purchase a product02, and that delivers the output to stakeholders. You can schedule the job with any tools that you prefer.
# <br>
#
# 2. Rewrite/restructure the existing codes if necessary, the purpose is to make the codes cleaner and easy to maintain.
# <br>
#
# 3. Use CI/CD pipeline to deploy the model, meaning you use CI/CD pipeline to create the weekly job instead of a manual process. This would make us very easy to make changes and continuously improve the model.
# <br>
#
# 4. Use MLFlow to keep track of the model.
#
# ### Hints
# 1. These tools can help you schedule your weekly job: crontab, airflow, or something on AWS, make sure that the job runs on a dockerized container
# 2. CI/CD tools: drone, Jenkins

# %% [markdown]
# ### Load py libaries

# %%
# The codes have been tested with python 3.7.9

from typing_extensions import Literal
# import all neccessary libraries
from datetime import datetime
from datetime import date

import numpy as np
import pandas as pd
import xgboost as xgb

from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from functools import partial
from hyperopt import fmin, tpe, STATUS_OK, Trials
from sklearn.metrics import confusion_matrix, roc_auc_score

from hyperopt import hp

import matplotlib.pyplot as plt
#import shap

# %% [markdown]
# ### Load the data

# %%
# load the data
data_file = 'telecom.csv'
raw_data = pd.read_csv(data_file)

# %%
raw_data.head()
# Out:
#    subscriber     income       age      var1 gender house_type  \
# 0           1  118239.80  74.32310  1.216512      f      OWNER
# 1           2  348760.40  45.86138  3.672188      f      OWNER
# 2           3   96111.34  43.18818  0.578956      f      OWNER
# 3           4   73818.17  43.32941 -0.129441      m     RENTAL
# 4           5   36469.51  34.87954 -0.127675      m     RENTAL
#
#         lastVisit product02
# 0   1/1/2012 2:09       Nee
# 1  1/1/2012 14:03        Ja
# 2  1/1/2012 23:58       Nee
# 3   1/2/2012 3:51        Ja
# 4  1/2/2012 13:50       Nee

# %% [markdown]
# ### Data Preparation

# %%
# prepare the data 

df = raw_data.copy()

# fill missing values
df[['gender', 'house_type']]= df[['gender', 'house_type']].fillna(value='missing')
df['income'] = df['income'].fillna((df['income'].mean()))
df['var1'] = df['var1'].fillna((df['var1'].mean()))
df['age'] = df['age'].fillna((df['age'].mean()))

# log transformation
df['income'] = np.log(df['income'])

# prepare target variable
df.loc[df.product02=='Nee', 'product02'] = 0
df.loc[df.product02=='Ja', 'product02'] = 1
df['product02'] = df.product02.astype(int)

# %%
# feature engineering
def calculate_duration(lastVisit):
    if lastVisit:
      lastVisit = datetime.strptime(lastVisit, "%m/%d/%Y %H:%M").date()
      today = date.today()
      return (today - lastVisit).days
    else:
      return 0

df['duration'] = df['lastVisit'].apply(calculate_duration)
df = df.drop(['subscriber','lastVisit'], axis=1)

# %%
# one-hot encoding the categorical features
df_X = df.loc[:, df.columns != 'product02']
df_X_onehot = pd.get_dummies(df_X, dummy_na=True)
df_onehot = pd.concat([df_X_onehot, df[['product02']]], axis=1)

# %%
strat = df['product02']
df_train, df_test = train_test_split(
        df_onehot,
        test_size=0.2,
        random_state=12345,
        stratify=strat)

df_train_X = df_train.loc[:, df_train.columns != 'product02']
df_train_y = df_train['product02']
df_test_X = df_test.loc[:, df_test.columns != 'product02']
df_test_y = df_test['product02']

# %%
df
# Out:
#          income       age      var1 gender house_type  product02  duration
# 0     11.680470  74.32310  1.216512      f      OWNER          0      4632
# 1     12.762140  45.86138  3.672188      f      OWNER          1      4632
# 2     11.473263  43.18818  0.578956      f      OWNER          0      4632
# 3     11.209360  43.32941 -0.129441      m     RENTAL          1      4631
# 4     10.504232  34.87954 -0.127675      m     RENTAL          0      4631
# ...         ...       ...       ...    ...        ...        ...       ...
# 9519  11.281307  29.57617  2.261101      m      OWNER          1      2846
# 9520  12.279089  46.34125  0.590807      f      OWNER          1      2846
# 9521  11.296737  37.10520 -0.099423      f     RENTAL          1      2846
# 9522  11.975464  65.85983 -0.263309      f     RENTAL          1      2846
# 9523  12.006838  40.13033  0.159354      f      OWNER          1      2845
#
# [9524 rows x 7 columns]

# %% [markdown]
# ## Model Training

# %%
def score(params):
    print("Training with params: ")
    print(params)
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    dtrain = xgb.DMatrix(df_train_X, label=df_train_y)
    dvalid = xgb.DMatrix(df_test_X, label=df_test_y)
    watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
    gbm_model = xgb.train(params, dtrain, num_round,
                          evals=watchlist,
                          verbose_eval=True)
    predictions = gbm_model.predict(dvalid,
                                    ntree_limit=gbm_model.best_iteration + 1)
    score = roc_auc_score(df_test_y, predictions)
    # TODO: Add the importance for the selected features
    #print(gbm_model.feature_importances_)
    print("\tScore {0}\n\n".format(score))
    # The score function should return the loss (1-score)
    # since the optimize function looks for the minimum
    loss = 1 - score
    return {'loss': loss, 'status': STATUS_OK}



def optimize(
             trials, 
             random_state=1998):
    """
    This is the optimization function that given a space (space here) of 
    hyperparameters and a scoring function (score here), finds the best hyperparameters.
    """
    # To learn more about XGBoost parameters, head to this page: 
    # https://github.com/dmlc/xgboost/blob/master/doc/parameter.md
    space = {
        'n_estimators': hp.quniform('n_estimators', 100, 1000, 1),
        'eta': hp.quniform('eta', 0.025, 0.5, 0.025),
        # A problem with max_depth casted to float instead of int with
        # the hp.quniform method.
        'max_depth':  hp.choice('max_depth', np.arange(1, 14, dtype=int)),
        'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
        'subsample': hp.quniform('subsample', 0.5, 1, 0.05),
        'gamma': hp.quniform('gamma', 0.5, 1, 0.05),
        'colsample_bytree': hp.quniform('colsample_bytree', 0.5, 1, 0.05),
        'eval_metric': 'auc',
        'objective': 'binary:logistic',
        # Increase this number if you have more cores. Otherwise, remove it and it will default 
        # to the maxium number. 
        'nthread': 4,
        'booster': 'gbtree',
        'tree_method': 'exact',
        'silent': 1,
        'seed': random_state
    }
    # Use the fmin function from Hyperopt to find the best hyperparameters
    best = fmin(score, space, algo=tpe.suggest, 
                trials=trials, 
                max_evals=250)
    return best


best_hyperparams = optimize(
                            Trials()
                            )
print("The best hyperparameters are: ", "\n")
print(best_hyperparams)
# Out:
# Training with params:
# {'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.5, 'eval_metric': 'auc', 'gamma': 0.6000000000000001, 'max_depth': 3, 'min_child_weight': 2.0, 'n_estimators': 968.0, 'nthread': 4, 'objective': 'binary:logistic', 'seed': 1998, 'silent': 1, 'subsample': 0.6000000000000001, 'tree_method': 'exact'}
# [0]	eval-auc:0.65701	train-auc:0.69072
# [1]	eval-auc:0.67164	train-auc:0.71285
# [2]	eval-auc:0.67449	train-auc:0.71850
# [3]	eval-auc:0.67576	train-auc:0.71933
# [4]	eval-auc:0.68124	train-auc:0.72309
# [5]	eval-auc:0.68129	train-auc:0.72411
# [6]	eval-auc:0.68352	train-auc:0.73262
# [7]	eval-auc:0.68405	train-auc:0.73425
# [8]	eval-auc:0.68627	train-auc:0.73961
# [9]	eval-auc:0.68800	train-auc:0.74104
# [10]	eval-auc:0.68686	train-auc:0.74257
# [11]	eval-auc:0.68617	train-auc:0.74600
# [12]	eval-auc:0.68671	train-auc:0.74912
# [13]	eval-auc:0.68612	train-auc:0.75124
# [14]	eval-auc:0.68654	train-auc:0.75263
# [15]	eval-auc:0.68562	train-auc:0.75463
# [16]	eval-auc:0.68364	train-auc:0.75515
# [17]	eval-auc:0.68684	train-auc:0.75685
# [18]	eval-auc:0.68825	train-auc:0.75821
# [19]	eval-auc:0.68812	train-auc:0.76112
# [20]	eval-auc:0.68727	train-auc:0.76218
# [21]	eval-auc:0.68425	train-auc:0.76465
# [22]	eval-auc:0.68305	train-auc:0.76551
# [23]	eval-auc:0.68333	train-auc:0.76648
# [24]	eval-auc:0.68413	train-auc:0.76708
# [25]	eval-auc:0.68482	train-auc:0.76747
# [26]	eval-auc:0.68551	train-auc:0.76883
# [27]	eval-auc:0.68417	train-auc:0.76911
# [28]	eval-auc:0.68332	train-auc:0.76929
# [29]	eval-auc:0.68365	train-auc:0.76979
# [30]	eval-auc:0.68276	train-auc:0.77142
# [31]	eval-auc:0.68041	train-auc:0.77459
# [32]	eval-auc:0.67946	train-auc:0.77534
# [33]	eval-auc:0.67975	train-auc:0.77691
# [34]	eval-auc:0.68171	train-auc:0.77705
# [35]	eval-auc:0.68184	train-auc:0.77799
# [36]	eval-auc:0.68267	train-auc:0.77856
# [37]	eval-auc:0.68185	train-auc:0.77902
# [38]	eval-auc:0.68344	train-auc:0.78025
#   0%|          | 0/250 [00:00<?, ?trial/s, best loss=?]
# /opt/homebrew/Caskroom/miniforge/base/envs/py38/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [14:34:15] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [39]	eval-auc:0.68204	train-auc:0.78163
# [40]	eval-auc:0.68084	train-auc:0.78339
# [41]	eval-auc:0.68105	train-auc:0.78428
# [42]	eval-auc:0.67968	train-auc:0.78494
# [43]	eval-auc:0.67987	train-auc:0.78542
# [44]	eval-auc:0.68099	train-auc:0.78579
# [45]	eval-auc:0.68407	train-auc:0.78665
# [46]	eval-auc:0.68284	train-auc:0.78787
# [47]	eval-auc:0.68079	train-auc:0.78874
# [48]	eval-auc:0.67988	train-auc:0.78975
# [49]	eval-auc:0.68153	train-auc:0.78910
# [50]	eval-auc:0.68008	train-auc:0.79116
# [51]	eval-auc:0.67903	train-auc:0.79328
# [52]	eval-auc:0.67726	train-auc:0.79514
# [53]	eval-auc:0.67866	train-auc:0.79686
# [54]	eval-auc:0.67959	train-auc:0.79778
# [55]	eval-auc:0.67935	train-auc:0.79877
# [56]	eval-auc:0.67856	train-auc:0.79996
# [57]	eval-auc:0.68079	train-auc:0.80082
# [58]	eval-auc:0.68016	train-auc:0.80151
# [59]	eval-auc:0.67970	train-auc:0.80301
# [60]	eval-auc:0.67883	train-auc:0.80374
# [61]	eval-auc:0.67986	train-auc:0.80382
# [62]	eval-auc:0.67969	train-auc:0.80489
# [63]	eval-auc:0.68141	train-auc:0.80565
# [64]	eval-auc:0.68072	train-auc:0.80658
# [65]	eval-auc:0.68181	train-auc:0.80699
# [66]	eval-auc:0.68068	train-auc:0.80741
# [67]	eval-auc:0.67969	train-auc:0.80945
# [68]	eval-auc:0.68159	train-auc:0.81120
# [69]	eval-auc:0.67976	train-auc:0.81218
# [70]	eval-auc:0.67966	train-auc:0.81340
# [71]	eval-auc:0.67992	train-auc:0.81303
# [72]	eval-auc:0.67943	train-auc:0.81303
# [73]	eval-auc:0.67845	train-auc:0.81470
# [74]	eval-auc:0.67644	train-auc:0.81513
# [75]	eval-auc:0.67469	train-auc:0.81659
# [76]	eval-auc:0.67589	train-auc:0.81666
# [77]	eval-auc:0.67659	train-auc:0.81810
# [78]	eval-auc:0.67926	train-auc:0.81935
# [79]	eval-auc:0.68012	train-auc:0.81997
# [80]	eval-auc:0.67981	train-auc:0.82039
# [81]	eval-auc:0.67942	train-auc:0.82029
# [82]	eval-auc:0.68008	train-auc:0.81995
# [83]	eval-auc:0.67788	train-auc:0.82093
# [84]	eval-auc:0.67962	train-auc:0.82121
# [85]	eval-auc:0.67965	train-auc:0.82106
# [86]	eval-auc:0.67908	train-auc:0.82163
# [87]	eval-auc:0.67803	train-auc:0.82227
# [88]	eval-auc:0.68035	train-auc:0.82246
# [89]	eval-auc:0.68033	train-auc:0.82261
# [90]	eval-auc:0.67956	train-auc:0.82338
# [91]	eval-auc:0.67968	train-auc:0.82442
# [92]	eval-auc:0.67852	train-auc:0.82502
# [93]	eval-auc:0.67691	train-auc:0.82535
# [94]	eval-auc:0.67685	train-auc:0.82587
# [95]	eval-auc:0.67770	train-auc:0.82610
# [96]	eval-auc:0.67597	train-auc:0.82694
# [97]	eval-auc:0.67663	train-auc:0.82747
# [98]	eval-auc:0.67575	train-auc:0.82801
# [99]	eval-auc:0.67555	train-auc:0.82930
# [100]	eval-auc:0.67589	train-auc:0.83063
# [101]	eval-auc:0.67698	train-auc:0.83058
# [102]	eval-auc:0.67799	train-auc:0.83073
# [103]	eval-auc:0.67826	train-auc:0.83162
# [104]	eval-auc:0.67939	train-auc:0.83242
# [105]	eval-auc:0.67835	train-auc:0.83271
# [106]	eval-auc:0.67864	train-auc:0.83330
# [107]	eval-auc:0.67722	train-auc:0.83317
# [108]	eval-auc:0.67579	train-auc:0.83441
# [109]	eval-auc:0.67678	train-auc:0.83470
# [110]	eval-auc:0.67328	train-auc:0.83483
# [111]	eval-auc:0.67452	train-auc:0.83621
# [112]	eval-auc:0.67231	train-auc:0.83720
# [113]	eval-auc:0.67047	train-auc:0.83780
# [114]	eval-auc:0.67156	train-auc:0.83870
# [115]	eval-auc:0.67173	train-auc:0.83921
# [116]	eval-auc:0.67127	train-auc:0.83928
# [117]	eval-auc:0.67143	train-auc:0.83965
# [118]	eval-auc:0.67045	train-auc:0.84011
# [119]	eval-auc:0.67125	train-auc:0.84030
# [120]	eval-auc:0.67122	train-auc:0.84053
# [121]	eval-auc:0.67133	train-auc:0.84082
# [122]	eval-auc:0.67157	train-auc:0.84104
# [123]	eval-auc:0.67288	train-auc:0.84147
# [124]	eval-auc:0.67235	train-auc:0.84296
# [125]	eval-auc:0.67120	train-auc:0.84392
# [126]	eval-auc:0.67187	train-auc:0.84391
# [127]	eval-auc:0.67219	train-auc:0.84399
# [128]	eval-auc:0.67290	train-auc:0.84397
# [129]	eval-auc:0.67253	train-auc:0.84566
# [130]	eval-auc:0.67527	train-auc:0.84621
# [131]	eval-auc:0.67317	train-auc:0.84678
# [132]	eval-auc:0.67361	train-auc:0.84648
# [133]	eval-auc:0.67330	train-auc:0.84657
# [134]	eval-auc:0.67239	train-auc:0.84717
# [135]	eval-auc:0.67087	train-auc:0.84780
# [136]	eval-auc:0.67228	train-auc:0.84785
# [137]	eval-auc:0.67116	train-auc:0.84892
# [138]	eval-auc:0.67190	train-auc:0.84856
# [139]	eval-auc:0.67347	train-auc:0.84846
# [140]	eval-auc:0.67318	train-auc:0.84932
# [141]	eval-auc:0.67220	train-auc:0.84978
# [142]	eval-auc:0.67189	train-auc:0.84994
# [143]	eval-auc:0.67190	train-auc:0.85054
# [144]	eval-auc:0.67257	train-auc:0.85045
# [145]	eval-auc:0.67215	train-auc:0.85077
# [146]	eval-auc:0.66941	train-auc:0.85125
# [147]	eval-auc:0.67025	train-auc:0.85134
# [148]	eval-auc:0.67019	train-auc:0.85142
# [149]	eval-auc:0.67045	train-auc:0.85134
# [150]	eval-auc:0.67028	train-auc:0.85155
# [151]	eval-auc:0.66968	train-auc:0.85196
# [152]	eval-auc:0.66899	train-auc:0.85269
# [153]	eval-auc:0.66773	train-auc:0.85316
# [154]	eval-auc:0.66584	train-auc:0.85367
# [155]	eval-auc:0.66516	train-auc:0.85456
# [156]	eval-auc:0.66651	train-auc:0.85461
# [157]	eval-auc:0.66704	train-auc:0.85538
# [158]	eval-auc:0.66641	train-auc:0.85638
# [159]	eval-auc:0.66773	train-auc:0.85672
# [160]	eval-auc:0.66757	train-auc:0.85808
# [161]	eval-auc:0.66728	train-auc:0.85865
# [162]	eval-auc:0.66888	train-auc:0.85908
# [163]	eval-auc:0.66863	train-auc:0.85971
# [164]	eval-auc:0.66877	train-auc:0.86021
# [165]	eval-auc:0.66965	train-auc:0.86052
# [166]	eval-auc:0.67057	train-auc:0.86139
# [167]	eval-auc:0.67060	train-auc:0.86119
# [168]	eval-auc:0.66973	train-auc:0.86178
# [169]	eval-auc:0.66832	train-auc:0.86263
# [170]	eval-auc:0.66747	train-auc:0.86417
# [171]	eval-auc:0.66642	train-auc:0.86477
# [172]	eval-auc:0.66681	train-auc:0.86580
# [173]	eval-auc:0.66868	train-auc:0.86568
# [174]	eval-auc:0.66949	train-auc:0.86663
# [175]	eval-auc:0.67077	train-auc:0.86689
# [176]	eval-auc:0.67095	train-auc:0.86793
# [177]	eval-auc:0.67193	train-auc:0.86845
# [178]	eval-auc:0.67370	train-auc:0.86880
# [179]	eval-auc:0.67340	train-auc:0.86888
# [180]	eval-auc:0.67460	train-auc:0.86933
# [181]	eval-auc:0.67523	train-auc:0.86951
# [182]	eval-auc:0.67511	train-auc:0.86950
# [183]	eval-auc:0.67621	train-auc:0.86931
# [184]	eval-auc:0.67503	train-auc:0.87067
# [185]	eval-auc:0.67534	train-auc:0.87061
# [186]	eval-auc:0.67551	train-auc:0.87087
# [187]	eval-auc:0.67461	train-auc:0.87128
# [188]	eval-auc:0.67530	train-auc:0.87177
# [189]	eval-auc:0.67386	train-auc:0.87245
# [190]	eval-auc:0.67513	train-auc:0.87288
# [191]	eval-auc:0.67614	train-auc:0.87341
# [192]	eval-auc:0.67516	train-auc:0.87335
# [193]	eval-auc:0.67540	train-auc:0.87403
# [194]	eval-auc:0.67469	train-auc:0.87414
# [195]	eval-auc:0.67420	train-auc:0.87452
# [196]	eval-auc:0.67414	train-auc:0.87478
# [197]	eval-auc:0.67549	train-auc:0.87513
# [198]	eval-auc:0.67533	train-auc:0.87553
# [199]	eval-auc:0.67481	train-auc:0.87605
# [200]	eval-auc:0.67477	train-auc:0.87686
# [201]	eval-auc:0.67465	train-auc:0.87695
# [202]	eval-auc:0.67495	train-auc:0.87774
# [203]	eval-auc:0.67479	train-auc:0.87757
# [204]	eval-auc:0.67363	train-auc:0.87809
# [205]	eval-auc:0.67343	train-auc:0.87863
# [206]	eval-auc:0.67504	train-auc:0.87900
# [207]	eval-auc:0.67582	train-auc:0.87872
# [208]	eval-auc:0.67631	train-auc:0.87846
# [209]	eval-auc:0.67646	train-auc:0.87853
# [210]	eval-auc:0.67614	train-auc:0.87869
# [211]	eval-auc:0.67626	train-auc:0.87932
# [212]	eval-auc:0.67566	train-auc:0.88024
# [213]	eval-auc:0.67657	train-auc:0.88034
# [214]	eval-auc:0.67596	train-auc:0.88042
# [215]	eval-auc:0.67560	train-auc:0.88094
# [216]	eval-auc:0.67559	train-auc:0.88104
# [217]	eval-auc:0.67588	train-auc:0.88116
# [218]	eval-auc:0.67399	train-auc:0.88168
# [219]	eval-auc:0.67362	train-auc:0.88170
# [220]	eval-auc:0.67314	train-auc:0.88210
# [221]	eval-auc:0.67401	train-auc:0.88270
# [222]	eval-auc:0.67348	train-auc:0.88284
# [223]	eval-auc:0.67389	train-auc:0.88273
# [224]	eval-auc:0.67559	train-auc:0.88296
# [225]	eval-auc:0.67509	train-auc:0.88419
# [226]	eval-auc:0.67533	train-auc:0.88421
# [227]	eval-auc:0.67515	train-auc:0.88459
# [228]	eval-auc:0.67667	train-auc:0.88423
# [229]	eval-auc:0.67582	train-auc:0.88519
# [230]	eval-auc:0.67558	train-auc:0.88528
# [231]	eval-auc:0.67613	train-auc:0.88566
# [232]	eval-auc:0.67603	train-auc:0.88683
# [233]	eval-auc:0.67558	train-auc:0.88658
# [234]	eval-auc:0.67562	train-auc:0.88702
# [235]	eval-auc:0.67592	train-auc:0.88757
# [236]	eval-auc:0.67621	train-auc:0.88741
# [237]	eval-auc:0.67693	train-auc:0.88736
# [238]	eval-auc:0.67802	train-auc:0.88836
# [239]	eval-auc:0.67731	train-auc:0.88952
# [240]	eval-auc:0.67690	train-auc:0.89003
# [241]	eval-auc:0.67728	train-auc:0.89041
# [242]	eval-auc:0.67593	train-auc:0.89119
# [243]	eval-auc:0.67635	train-auc:0.89114
# [244]	eval-auc:0.67709	train-auc:0.89135
# [245]	eval-auc:0.67725	train-auc:0.89175
# [246]	eval-auc:0.67711	train-auc:0.89236
# [247]	eval-auc:0.67743	train-auc:0.89228
# [248]	eval-auc:0.67809	train-auc:0.89289
# [249]	eval-auc:0.67756	train-auc:0.89289
# [250]	eval-auc:0.67825	train-auc:0.89320
# [251]	eval-auc:0.67728	train-auc:0.89349
# [252]	eval-auc:0.67938	train-auc:0.89344
# [253]	eval-auc:0.67896	train-auc:0.89419
# [254]	eval-auc:0.67824	train-auc:0.89472
# [255]	eval-auc:0.67739	train-auc:0.89519
# [256]	eval-auc:0.67820	train-auc:0.89508
# [257]	eval-auc:0.67868	train-auc:0.89558
# [258]	eval-auc:0.67963	train-auc:0.89582
# [259]	eval-auc:0.67955	train-auc:0.89619
# [260]	eval-auc:0.67783	train-auc:0.89659
# [261]	eval-auc:0.67859	train-auc:0.89635
# [262]	eval-auc:0.67912	train-auc:0.89716
# [263]	eval-auc:0.67777	train-auc:0.89764
# [264]	eval-auc:0.67849	train-auc:0.89706
# [265]	eval-auc:0.67812	train-auc:0.89714
# [266]	eval-auc:0.67657	train-auc:0.89815
# [267]	eval-auc:0.67668	train-auc:0.89910
# [268]	eval-auc:0.67669	train-auc:0.89914
# [269]	eval-auc:0.67862	train-auc:0.89888
# [270]	eval-auc:0.67790	train-auc:0.89957
# [271]	eval-auc:0.67721	train-auc:0.89992
# [272]	eval-auc:0.67719	train-auc:0.90014
# [273]	eval-auc:0.67592	train-auc:0.90066
# [274]	eval-auc:0.67649	train-auc:0.90081
# [275]	eval-auc:0.67737	train-auc:0.90069
# [276]	eval-auc:0.67750	train-auc:0.90087
# [277]	eval-auc:0.67755	train-auc:0.90131
# [278]	eval-auc:0.67701	train-auc:0.90105
# [279]	eval-auc:0.67646	train-auc:0.90116
# [280]	eval-auc:0.67695	train-auc:0.90236
# [281]	eval-auc:0.67670	train-auc:0.90273
# [282]	eval-auc:0.67735	train-auc:0.90239
# [283]	eval-auc:0.67613	train-auc:0.90300
# [284]	eval-auc:0.67521	train-auc:0.90340
# [285]	eval-auc:0.67559	train-auc:0.90357
# [286]	eval-auc:0.67539	train-auc:0.90386
# [287]	eval-auc:0.67711	train-auc:0.90377
# [288]	eval-auc:0.67705	train-auc:0.90457
# [289]	eval-auc:0.67728	train-auc:0.90489
# [290]	eval-auc:0.67767	train-auc:0.90481
# [291]	eval-auc:0.67843	train-auc:0.90505
# [292]	eval-auc:0.67762	train-auc:0.90555
# [293]	eval-auc:0.67717	train-auc:0.90577
# [294]	eval-auc:0.67684	train-auc:0.90610
# [295]	eval-auc:0.67605	train-auc:0.90622
# [296]	eval-auc:0.67648	train-auc:0.90659
# [297]	eval-auc:0.67828	train-auc:0.90648
# [298]	eval-auc:0.67822	train-auc:0.90707
# [299]	eval-auc:0.67881	train-auc:0.90707
# [300]	eval-auc:0.67735	train-auc:0.90730
# [301]	eval-auc:0.67689	train-auc:0.90801
# [302]	eval-auc:0.67741	train-auc:0.90798
# [303]	eval-auc:0.67682	train-auc:0.90852
# [304]	eval-auc:0.67590	train-auc:0.90897
# [305]	eval-auc:0.67457	train-auc:0.90938
# [306]	eval-auc:0.67614	train-auc:0.90964
# [307]	eval-auc:0.67535	train-auc:0.90985
# [308]	eval-auc:0.67489	train-auc:0.91010
# [309]	eval-auc:0.67524	train-auc:0.91036
# [310]	eval-auc:0.67521	train-auc:0.91065
# [311]	eval-auc:0.67514	train-auc:0.91089
# [312]	eval-auc:0.67506	train-auc:0.91122
# [313]	eval-auc:0.67355	train-auc:0.91207
# [314]	eval-auc:0.67289	train-auc:0.91220
# [315]	eval-auc:0.67469	train-auc:0.91230
# [316]	eval-auc:0.67452	train-auc:0.91335
# [317]	eval-auc:0.67483	train-auc:0.91289
# [318]	eval-auc:0.67425	train-auc:0.91315
# [319]	eval-auc:0.67358	train-auc:0.91308
# [320]	eval-auc:0.67418	train-auc:0.91365
# [321]	eval-auc:0.67412	train-auc:0.91390
# [322]	eval-auc:0.67485	train-auc:0.91411
# [323]	eval-auc:0.67511	train-auc:0.91430
# [324]	eval-auc:0.67405	train-auc:0.91450
# [325]	eval-auc:0.67572	train-auc:0.91437
# [326]	eval-auc:0.67619	train-auc:0.91440
# [327]	eval-auc:0.67563	train-auc:0.91476
# [328]	eval-auc:0.67451	train-auc:0.91535
# [329]	eval-auc:0.67548	train-auc:0.91511
# [330]	eval-auc:0.67427	train-auc:0.91596
# [331]	eval-auc:0.67396	train-auc:0.91627
# [332]	eval-auc:0.67372	train-auc:0.91670
# [333]	eval-auc:0.67410	train-auc:0.91633
# [334]	eval-auc:0.67448	train-auc:0.91657
# [335]	eval-auc:0.67539	train-auc:0.91662
# [336]	eval-auc:0.67428	train-auc:0.91711
# [337]	eval-auc:0.67561	train-auc:0.91658
# [338]	eval-auc:0.67583	train-auc:0.91690
# [339]	eval-auc:0.67559	train-auc:0.91701
# [340]	eval-auc:0.67633	train-auc:0.91706
# [341]	eval-auc:0.67591	train-auc:0.91762
# [342]	eval-auc:0.67725	train-auc:0.91768
# [343]	eval-auc:0.67770	train-auc:0.91811
# [344]	eval-auc:0.67705	train-auc:0.91871
# [345]	eval-auc:0.67741	train-auc:0.91905
# [346]	eval-auc:0.67683	train-auc:0.91923
# [347]	eval-auc:0.67838	train-auc:0.91941
# [348]	eval-auc:0.67731	train-auc:0.91936
# [349]	eval-auc:0.67521	train-auc:0.92018
# [350]	eval-auc:0.67501	train-auc:0.92130
# [351]	eval-auc:0.67598	train-auc:0.92052
# [352]	eval-auc:0.67477	train-auc:0.92096
# [353]	eval-auc:0.67541	train-auc:0.92083
# [354]	eval-auc:0.67577	train-auc:0.92093
# [355]	eval-auc:0.67539	train-auc:0.92109
# [356]	eval-auc:0.67671	train-auc:0.92173
# [357]	eval-auc:0.67758	train-auc:0.92190
# [358]	eval-auc:0.67757	train-auc:0.92204
# [359]	eval-auc:0.67708	train-auc:0.92234
# [360]	eval-auc:0.67525	train-auc:0.92229
# [361]	eval-auc:0.67417	train-auc:0.92327
# [362]	eval-auc:0.67263	train-auc:0.92415
# [363]	eval-auc:0.67345	train-auc:0.92432
# [364]	eval-auc:0.67502	train-auc:0.92378
# [365]	eval-auc:0.67370	train-auc:0.92402
# [366]	eval-auc:0.67258	train-auc:0.92477
# [367]	eval-auc:0.67254	train-auc:0.92506
# [368]	eval-auc:0.67258	train-auc:0.92462
# [369]	eval-auc:0.67381	train-auc:0.92513
# [370]	eval-auc:0.67396	train-auc:0.92463
# [371]	eval-auc:0.67448	train-auc:0.92526
# [372]	eval-auc:0.67377	train-auc:0.92592
# [373]	eval-auc:0.67328	train-auc:0.92605
# [374]	eval-auc:0.67367	train-auc:0.92679
# [375]	eval-auc:0.67398	train-auc:0.92680
# [376]	eval-auc:0.67531	train-auc:0.92695
# [377]	eval-auc:0.67631	train-auc:0.92647
# [378]	eval-auc:0.67736	train-auc:0.92714
# [379]	eval-auc:0.67893	train-auc:0.92708
# [380]	eval-auc:0.67712	train-auc:0.92749
# [381]	eval-auc:0.67642	train-auc:0.92772
# [382]	eval-auc:0.67631	train-auc:0.92803
# [383]	eval-auc:0.67706	train-auc:0.92850
# [384]	eval-auc:0.67717	train-auc:0.92874
# [385]	eval-auc:0.67720	train-auc:0.92938
# [386]	eval-auc:0.67732	train-auc:0.92948
# [387]	eval-auc:0.67796	train-auc:0.92967
# [388]	eval-auc:0.67794	train-auc:0.92983
# [389]	eval-auc:0.67856	train-auc:0.92981
# [390]	eval-auc:0.68035	train-auc:0.92961
# [391]	eval-auc:0.67802	train-auc:0.93038
# [392]	eval-auc:0.67762	train-auc:0.93092
# [393]	eval-auc:0.67743	train-auc:0.93119
# [394]	eval-auc:0.67643	train-auc:0.93166
# [395]	eval-auc:0.67589	train-auc:0.93208
# [396]	eval-auc:0.67653	train-auc:0.93221
# [397]	eval-auc:0.67598	train-auc:0.93237
# [398]	eval-auc:0.67649	train-auc:0.93214
# [399]	eval-auc:0.67675	train-auc:0.93217
# [400]	eval-auc:0.67697	train-auc:0.93233
# [401]	eval-auc:0.67658	train-auc:0.93239
# [402]	eval-auc:0.67720	train-auc:0.93258
# [403]	eval-auc:0.67833	train-auc:0.93267
# [404]	eval-auc:0.67919	train-auc:0.93279
# [405]	eval-auc:0.67899	train-auc:0.93273
# [406]	eval-auc:0.67821	train-auc:0.93276
# [407]	eval-auc:0.67793	train-auc:0.93287
# [408]	eval-auc:0.67736	train-auc:0.93359
# [409]	eval-auc:0.67735	train-auc:0.93378
# [410]	eval-auc:0.67768	train-auc:0.93407
# [411]	eval-auc:0.67654	train-auc:0.93431
# [412]	eval-auc:0.67599	train-auc:0.93450
# [413]	eval-auc:0.67645	train-auc:0.93469
# [414]	eval-auc:0.67708	train-auc:0.93439
# [415]	eval-auc:0.67646	train-auc:0.93496
# [416]	eval-auc:0.67664	train-auc:0.93486
# [417]	eval-auc:0.67633	train-auc:0.93536
# [418]	eval-auc:0.67785	train-auc:0.93451
# [419]	eval-auc:0.67792	train-auc:0.93453
# [420]	eval-auc:0.67760	train-auc:0.93495
# [421]	eval-auc:0.67675	train-auc:0.93604
# [422]	eval-auc:0.67753	train-auc:0.93580
# [423]	eval-auc:0.67823	train-auc:0.93584
# [424]	eval-auc:0.67798	train-auc:0.93652
# [425]	eval-auc:0.67798	train-auc:0.93646
# [426]	eval-auc:0.67759	train-auc:0.93678
# [427]	eval-auc:0.67801	train-auc:0.93680
# [428]	eval-auc:0.67908	train-auc:0.93690
# [429]	eval-auc:0.67778	train-auc:0.93727
# [430]	eval-auc:0.67762	train-auc:0.93730
# [431]	eval-auc:0.67799	train-auc:0.93706
# [432]	eval-auc:0.67738	train-auc:0.93776
# [433]	eval-auc:0.67823	train-auc:0.93755
# [434]	eval-auc:0.67796	train-auc:0.93815
# [435]	eval-auc:0.67711	train-auc:0.93845
# [436]	eval-auc:0.67680	train-auc:0.93853
# [437]	eval-auc:0.67773	train-auc:0.93848
# [438]	eval-auc:0.67698	train-auc:0.93876
# [439]	eval-auc:0.67625	train-auc:0.93930
# [440]	eval-auc:0.67631	train-auc:0.93951
# [441]	eval-auc:0.67646	train-auc:0.93947
# [442]	eval-auc:0.67730	train-auc:0.93980
# [443]	eval-auc:0.67747	train-auc:0.93972
# [444]	eval-auc:0.67781	train-auc:0.93996
# [445]	eval-auc:0.67833	train-auc:0.94043
# [446]	eval-auc:0.67821	train-auc:0.94038
# [447]	eval-auc:0.67789	train-auc:0.94052
# [448]	eval-auc:0.67866	train-auc:0.94038
# [449]	eval-auc:0.67806	train-auc:0.94062
# [450]	eval-auc:0.67946	train-auc:0.94058
# [451]	eval-auc:0.67957	train-auc:0.94126
# [452]	eval-auc:0.67870	train-auc:0.94193
# [453]	eval-auc:0.67836	train-auc:0.94247
# [454]	eval-auc:0.67812	train-auc:0.94292
# [455]	eval-auc:0.67816	train-auc:0.94323
# [456]	eval-auc:0.67870	train-auc:0.94294
# [457]	eval-auc:0.67983	train-auc:0.94328
# [458]	eval-auc:0.67903	train-auc:0.94371
# [459]	eval-auc:0.67782	train-auc:0.94429
# [460]	eval-auc:0.67937	train-auc:0.94431
# [461]	eval-auc:0.67933	train-auc:0.94419
# [462]	eval-auc:0.67909	train-auc:0.94414
# [463]	eval-auc:0.68054	train-auc:0.94438
# [464]	eval-auc:0.68181	train-auc:0.94445
# [465]	eval-auc:0.68051	train-auc:0.94510
# [466]	eval-auc:0.68006	train-auc:0.94535
# [467]	eval-auc:0.68016	train-auc:0.94521
# [468]	eval-auc:0.67953	train-auc:0.94555
# [469]	eval-auc:0.67858	train-auc:0.94578
# [470]	eval-auc:0.67937	train-auc:0.94585
# [471]	eval-auc:0.67930	train-auc:0.94583
# [472]	eval-auc:0.67956	train-auc:0.94555
# [473]	eval-auc:0.68015	train-auc:0.94650
# [474]	eval-auc:0.68148	train-auc:0.94594
# [475]	eval-auc:0.68172	train-auc:0.94623
# [476]	eval-auc:0.68043	train-auc:0.94648
# [477]	eval-auc:0.68163	train-auc:0.94630
# [478]	eval-auc:0.68184	train-auc:0.94635
# [479]	eval-auc:0.68091	train-auc:0.94670
# [480]	eval-auc:0.68065	train-auc:0.94700
# [481]	eval-auc:0.68186	train-auc:0.94664
# [482]	eval-auc:0.68137	train-auc:0.94711
# [483]	eval-auc:0.68107	train-auc:0.94731
# [484]	eval-auc:0.68066	train-auc:0.94770
# [485]	eval-auc:0.68163	train-auc:0.94735
# [486]	eval-auc:0.68172	train-auc:0.94732
# [487]	eval-auc:0.68258	train-auc:0.94743
# [488]	eval-auc:0.68242	train-auc:0.94788
# [489]	eval-auc:0.68189	train-auc:0.94775
# [490]	eval-auc:0.68176	train-auc:0.94856
# [491]	eval-auc:0.68233	train-auc:0.94892
# [492]	eval-auc:0.68221	train-auc:0.94890
# [493]	eval-auc:0.68177	train-auc:0.94915
# [494]	eval-auc:0.68264	train-auc:0.94870
# [495]	eval-auc:0.68267	train-auc:0.94872
# [496]	eval-auc:0.68315	train-auc:0.94885
# [497]	eval-auc:0.68370	train-auc:0.94917
# [498]	eval-auc:0.68261	train-auc:0.94910
# [499]	eval-auc:0.68294	train-auc:0.94945
# [500]	eval-auc:0.68417	train-auc:0.94930
# [501]	eval-auc:0.68472	train-auc:0.94979
# [502]	eval-auc:0.68464	train-auc:0.94999
# [503]	eval-auc:0.68328	train-auc:0.95053
# [504]	eval-auc:0.68249	train-auc:0.95100
# [505]	eval-auc:0.68192	train-auc:0.95123
# [506]	eval-auc:0.68215	train-auc:0.95099
# [507]	eval-auc:0.68293	train-auc:0.95092
# [508]	eval-auc:0.68271	train-auc:0.95143
# [509]	eval-auc:0.68263	train-auc:0.95140
# [510]	eval-auc:0.68253	train-auc:0.95136
# [511]	eval-auc:0.68333	train-auc:0.95119
# [512]	eval-auc:0.68374	train-auc:0.95130
# [513]	eval-auc:0.68374	train-auc:0.95149
# [514]	eval-auc:0.68402	train-auc:0.95121
# [515]	eval-auc:0.68396	train-auc:0.95209
# [516]	eval-auc:0.68291	train-auc:0.95243
# [517]	eval-auc:0.68343	train-auc:0.95205
# [518]	eval-auc:0.68328	train-auc:0.95216
# [519]	eval-auc:0.68359	train-auc:0.95232
# [520]	eval-auc:0.68296	train-auc:0.95240
# [521]	eval-auc:0.68298	train-auc:0.95248
# [522]	eval-auc:0.68358	train-auc:0.95214
# [523]	eval-auc:0.68339	train-auc:0.95217
# [524]	eval-auc:0.68328	train-auc:0.95293
# [525]	eval-auc:0.68230	train-auc:0.95351
# [526]	eval-auc:0.68197	train-auc:0.95385
# [527]	eval-auc:0.68300	train-auc:0.95384
# [528]	eval-auc:0.68266	train-auc:0.95357
# [529]	eval-auc:0.68109	train-auc:0.95438
# [530]	eval-auc:0.68209	train-auc:0.95397
# [531]	eval-auc:0.68178	train-auc:0.95357
# [532]	eval-auc:0.67955	train-auc:0.95481
# [533]	eval-auc:0.68053	train-auc:0.95458
# [534]	eval-auc:0.68101	train-auc:0.95484
# [535]	eval-auc:0.68172	train-auc:0.95420
# [536]	eval-auc:0.68196	train-auc:0.95427
# [537]	eval-auc:0.68092	train-auc:0.95497
# [538]	eval-auc:0.68111	train-auc:0.95531
# [539]	eval-auc:0.67997	train-auc:0.95520
# [540]	eval-auc:0.67984	train-auc:0.95517
# [541]	eval-auc:0.67995	train-auc:0.95528
# [542]	eval-auc:0.68036	train-auc:0.95539
# [543]	eval-auc:0.68163	train-auc:0.95507
# [544]	eval-auc:0.68114	train-auc:0.95559
# [545]	eval-auc:0.68166	train-auc:0.95525
# [546]	eval-auc:0.68062	train-auc:0.95605
# [547]	eval-auc:0.67956	train-auc:0.95637
# [548]	eval-auc:0.67875	train-auc:0.95640
# [549]	eval-auc:0.67910	train-auc:0.95668
# [550]	eval-auc:0.67989	train-auc:0.95657
# [551]	eval-auc:0.68048	train-auc:0.95640
# [552]	eval-auc:0.68109	train-auc:0.95609
# [553]	eval-auc:0.68250	train-auc:0.95582
# [554]	eval-auc:0.68425	train-auc:0.95613
# [555]	eval-auc:0.68446	train-auc:0.95617
# [556]	eval-auc:0.68515	train-auc:0.95607
# [557]	eval-auc:0.68460	train-auc:0.95632
# [558]	eval-auc:0.68392	train-auc:0.95630
# [559]	eval-auc:0.68437	train-auc:0.95615
# [560]	eval-auc:0.68518	train-auc:0.95581
# [561]	eval-auc:0.68417	train-auc:0.95578
# [562]	eval-auc:0.68351	train-auc:0.95620
# [563]	eval-auc:0.68317	train-auc:0.95662
# [564]	eval-auc:0.68302	train-auc:0.95727
# [565]	eval-auc:0.68383	train-auc:0.95715
# [566]	eval-auc:0.68432	train-auc:0.95738
# [567]	eval-auc:0.68455	train-auc:0.95780
# [568]	eval-auc:0.68455	train-auc:0.95758
# [569]	eval-auc:0.68429	train-auc:0.95785
# [570]	eval-auc:0.68430	train-auc:0.95806
# [571]	eval-auc:0.68425	train-auc:0.95833
# [572]	eval-auc:0.68419	train-auc:0.95867
# [573]	eval-auc:0.68536	train-auc:0.95845
# [574]	eval-auc:0.68361	train-auc:0.95923
# [575]	eval-auc:0.68352	train-auc:0.95945
# [576]	eval-auc:0.68354	train-auc:0.95919
# [577]	eval-auc:0.68393	train-auc:0.95893
# [578]	eval-auc:0.68494	train-auc:0.95888
# [579]	eval-auc:0.68421	train-auc:0.95913
# [580]	eval-auc:0.68367	train-auc:0.95936
# [581]	eval-auc:0.68420	train-auc:0.95917
# [582]	eval-auc:0.68429	train-auc:0.95954
# [583]	eval-auc:0.68369	train-auc:0.96007
# [584]	eval-auc:0.68319	train-auc:0.96050
# [585]	eval-auc:0.68282	train-auc:0.96035
# [586]	eval-auc:0.68290	train-auc:0.96058
# [587]	eval-auc:0.68217	train-auc:0.96052
# [588]	eval-auc:0.68256	train-auc:0.96065
# [589]	eval-auc:0.68280	train-auc:0.96054
# [590]	eval-auc:0.68304	train-auc:0.96058
# [591]	eval-auc:0.68420	train-auc:0.96069
# [592]	eval-auc:0.68424	train-auc:0.96044
# [593]	eval-auc:0.68436	train-auc:0.96048
# [594]	eval-auc:0.68496	train-auc:0.96074
# [595]	eval-auc:0.68614	train-auc:0.96098
# [596]	eval-auc:0.68570	train-auc:0.96087
# [597]	eval-auc:0.68630	train-auc:0.96087
# [598]	eval-auc:0.68674	train-auc:0.96090
# [599]	eval-auc:0.68416	train-auc:0.96182
# [600]	eval-auc:0.68469	train-auc:0.96173
# [601]	eval-auc:0.68470	train-auc:0.96172
# [602]	eval-auc:0.68455	train-auc:0.96164
# [603]	eval-auc:0.68360	train-auc:0.96212
# [604]	eval-auc:0.68383	train-auc:0.96233
# [605]	eval-auc:0.68444	train-auc:0.96204
# [606]	eval-auc:0.68398	train-auc:0.96181
# [607]	eval-auc:0.68395	train-auc:0.96240
# [608]	eval-auc:0.68388	train-auc:0.96248
# [609]	eval-auc:0.68310	train-auc:0.96290
# [610]	eval-auc:0.68284	train-auc:0.96302
# [611]	eval-auc:0.68326	train-auc:0.96301
# [612]	eval-auc:0.68367	train-auc:0.96290
# [613]	eval-auc:0.68363	train-auc:0.96314
# [614]	eval-auc:0.68295	train-auc:0.96317
# [615]	eval-auc:0.68315	train-auc:0.96355
# [616]	eval-auc:0.68287	train-auc:0.96359
# [617]	eval-auc:0.68251	train-auc:0.96357
# [618]	eval-auc:0.68202	train-auc:0.96346
# [619]	eval-auc:0.68272	train-auc:0.96314
# [620]	eval-auc:0.68199	train-auc:0.96325
# [621]	eval-auc:0.68097	train-auc:0.96338
# [622]	eval-auc:0.68174	train-auc:0.96322
# [623]	eval-auc:0.68142	train-auc:0.96392
# [624]	eval-auc:0.68103	train-auc:0.96377
# [625]	eval-auc:0.68201	train-auc:0.96343
# [626]	eval-auc:0.68264	train-auc:0.96343
# [627]	eval-auc:0.68262	train-auc:0.96349
# [628]	eval-auc:0.68275	train-auc:0.96387
# [629]	eval-auc:0.68493	train-auc:0.96366
# [630]	eval-auc:0.68447	train-auc:0.96376
# [631]	eval-auc:0.68429	train-auc:0.96443
# [632]	eval-auc:0.68363	train-auc:0.96475
# [633]	eval-auc:0.68386	train-auc:0.96483
# [634]	eval-auc:0.68406	train-auc:0.96488
# [635]	eval-auc:0.68427	train-auc:0.96511
# [636]	eval-auc:0.68406	train-auc:0.96489
# [637]	eval-auc:0.68282	train-auc:0.96567
# [638]	eval-auc:0.68387	train-auc:0.96537
# [639]	eval-auc:0.68344	train-auc:0.96534
# [640]	eval-auc:0.68378	train-auc:0.96548
# [641]	eval-auc:0.68252	train-auc:0.96559
# [642]	eval-auc:0.68236	train-auc:0.96545
# [643]	eval-auc:0.68238	train-auc:0.96588
# [644]	eval-auc:0.68343	train-auc:0.96611
# [645]	eval-auc:0.68338	train-auc:0.96606
# [646]	eval-auc:0.68472	train-auc:0.96543
# [647]	eval-auc:0.68310	train-auc:0.96606
# [648]	eval-auc:0.68305	train-auc:0.96631
# [649]	eval-auc:0.68373	train-auc:0.96626
# [650]	eval-auc:0.68393	train-auc:0.96613
# [651]	eval-auc:0.68367	train-auc:0.96607
# [652]	eval-auc:0.68452	train-auc:0.96625
# [653]	eval-auc:0.68450	train-auc:0.96660
# [654]	eval-auc:0.68496	train-auc:0.96690
# [655]	eval-auc:0.68488	train-auc:0.96721
# [656]	eval-auc:0.68473	train-auc:0.96734
# [657]	eval-auc:0.68469	train-auc:0.96730
# [658]	eval-auc:0.68558	train-auc:0.96683
# [659]	eval-auc:0.68630	train-auc:0.96661
# [660]	eval-auc:0.68502	train-auc:0.96700
# [661]	eval-auc:0.68451	train-auc:0.96739
# [662]	eval-auc:0.68348	train-auc:0.96795
# [663]	eval-auc:0.68449	train-auc:0.96778
# [664]	eval-auc:0.68388	train-auc:0.96791
# [665]	eval-auc:0.68458	train-auc:0.96780
# [666]	eval-auc:0.68464	train-auc:0.96784
# [667]	eval-auc:0.68595	train-auc:0.96790
# [668]	eval-auc:0.68606	train-auc:0.96814
# [669]	eval-auc:0.68691	train-auc:0.96765
# [670]	eval-auc:0.68748	train-auc:0.96739
# [671]	eval-auc:0.68614	train-auc:0.96828
# [672]	eval-auc:0.68614	train-auc:0.96824
# [673]	eval-auc:0.68524	train-auc:0.96852
# [674]	eval-auc:0.68532	train-auc:0.96875
# [675]	eval-auc:0.68524	train-auc:0.96883
# [676]	eval-auc:0.68524	train-auc:0.96882
# [677]	eval-auc:0.68600	train-auc:0.96870
# [678]	eval-auc:0.68640	train-auc:0.96871
# [679]	eval-auc:0.68597	train-auc:0.96878
# [680]	eval-auc:0.68541	train-auc:0.96892
# [681]	eval-auc:0.68586	train-auc:0.96893
# [682]	eval-auc:0.68526	train-auc:0.96918
# [683]	eval-auc:0.68545	train-auc:0.96956
# [684]	eval-auc:0.68573	train-auc:0.96945
# [685]	eval-auc:0.68514	train-auc:0.96956
# [686]	eval-auc:0.68567	train-auc:0.96922
# [687]	eval-auc:0.68514	train-auc:0.96935
# [688]	eval-auc:0.68345	train-auc:0.96967
# [689]	eval-auc:0.68326	train-auc:0.96962
# [690]	eval-auc:0.68239	train-auc:0.96983
# [691]	eval-auc:0.68214	train-auc:0.96985
# [692]	eval-auc:0.68232	train-auc:0.96985
# [693]	eval-auc:0.68256	train-auc:0.97014
# [694]	eval-auc:0.68348	train-auc:0.96987
# [695]	eval-auc:0.68404	train-auc:0.96957
# [696]	eval-auc:0.68452	train-auc:0.96971
# [697]	eval-auc:0.68525	train-auc:0.96989
# [698]	eval-auc:0.68581	train-auc:0.96977
# [699]	eval-auc:0.68593	train-auc:0.97025
# [700]	eval-auc:0.68513	train-auc:0.97051
# [701]	eval-auc:0.68589	train-auc:0.97047
# [702]	eval-auc:0.68544	train-auc:0.97058
# [703]	eval-auc:0.68508	train-auc:0.97085
# [704]	eval-auc:0.68571	train-auc:0.97102
# [705]	eval-auc:0.68593	train-auc:0.97101
# [706]	eval-auc:0.68546	train-auc:0.97134
# [707]	eval-auc:0.68527	train-auc:0.97119
# [708]	eval-auc:0.68558	train-auc:0.97132
# [709]	eval-auc:0.68525	train-auc:0.97118
# [710]	eval-auc:0.68513	train-auc:0.97154
# [711]	eval-auc:0.68352	train-auc:0.97176
# [712]	eval-auc:0.68379	train-auc:0.97181
# [713]	eval-auc:0.68309	train-auc:0.97188
# [714]	eval-auc:0.68291	train-auc:0.97215
# [715]	eval-auc:0.68225	train-auc:0.97231
# [716]	eval-auc:0.68297	train-auc:0.97218
# [717]	eval-auc:0.68305	train-auc:0.97224
# [718]	eval-auc:0.68387	train-auc:0.97214
# [719]	eval-auc:0.68402	train-auc:0.97240
# [720]	eval-auc:0.68371	train-auc:0.97252
# [721]	eval-auc:0.68472	train-auc:0.97275
# [722]	eval-auc:0.68381	train-auc:0.97289
# [723]	eval-auc:0.68384	train-auc:0.97289
# [724]	eval-auc:0.68416	train-auc:0.97283
# [725]	eval-auc:0.68339	train-auc:0.97322
# [726]	eval-auc:0.68302	train-auc:0.97341
# [727]	eval-auc:0.68377	train-auc:0.97349
# [728]	eval-auc:0.68421	train-auc:0.97332
# [729]	eval-auc:0.68479	train-auc:0.97329
# [730]	eval-auc:0.68479	train-auc:0.97297
# [731]	eval-auc:0.68493	train-auc:0.97295
# [732]	eval-auc:0.68463	train-auc:0.97279
# [733]	eval-auc:0.68471	train-auc:0.97341
# [734]	eval-auc:0.68598	train-auc:0.97289
# [735]	eval-auc:0.68601	train-auc:0.97282
# [736]	eval-auc:0.68573	train-auc:0.97295
# [737]	eval-auc:0.68579	train-auc:0.97311
# [738]	eval-auc:0.68545	train-auc:0.97309
# [739]	eval-auc:0.68569	train-auc:0.97364
# [740]	eval-auc:0.68542	train-auc:0.97386
# [741]	eval-auc:0.68502	train-auc:0.97400
# [742]	eval-auc:0.68497	train-auc:0.97423
# [743]	eval-auc:0.68547	train-auc:0.97378
# [744]	eval-auc:0.68510	train-auc:0.97388
# [745]	eval-auc:0.68525	train-auc:0.97378
# [746]	eval-auc:0.68482	train-auc:0.97371
# [747]	eval-auc:0.68548	train-auc:0.97359
# [748]	eval-auc:0.68410	train-auc:0.97417
# [749]	eval-auc:0.68347	train-auc:0.97436
# [750]	eval-auc:0.68300	train-auc:0.97413
# [751]	eval-auc:0.68383	train-auc:0.97440
# [752]	eval-auc:0.68520	train-auc:0.97427
# [753]	eval-auc:0.68523	train-auc:0.97444
# [754]	eval-auc:0.68372	train-auc:0.97468
# [755]	eval-auc:0.68416	train-auc:0.97486
# [756]	eval-auc:0.68276	train-auc:0.97497
# [757]	eval-auc:0.68289	train-auc:0.97498
# [758]	eval-auc:0.68382	train-auc:0.97465
# [759]	eval-auc:0.68384	train-auc:0.97503
# [760]	eval-auc:0.68365	train-auc:0.97521
# [761]	eval-auc:0.68405	train-auc:0.97534
# [762]	eval-auc:0.68444	train-auc:0.97541
# [763]	eval-auc:0.68331	train-auc:0.97577
# [764]	eval-auc:0.68333	train-auc:0.97559
# [765]	eval-auc:0.68348	train-auc:0.97565
# [766]	eval-auc:0.68293	train-auc:0.97551
# [767]	eval-auc:0.68292	train-auc:0.97545
# [768]	eval-auc:0.68221	train-auc:0.97558
# [769]	eval-auc:0.68226	train-auc:0.97568
# [770]	eval-auc:0.68166	train-auc:0.97624
# [771]	eval-auc:0.68289	train-auc:0.97623
# [772]	eval-auc:0.68275	train-auc:0.97639
# [773]	eval-auc:0.68355	train-auc:0.97624
# [774]	eval-auc:0.68373	train-auc:0.97621
# [775]	eval-auc:0.68422	train-auc:0.97638
# [776]	eval-auc:0.68443	train-auc:0.97656
# [777]	eval-auc:0.68510	train-auc:0.97644
# [778]	eval-auc:0.68475	train-auc:0.97671
# [779]	eval-auc:0.68466	train-auc:0.97676
# [780]	eval-auc:0.68489	train-auc:0.97677
# [781]	eval-auc:0.68464	train-auc:0.97691
# [782]	eval-auc:0.68418	train-auc:0.97669
# [783]	eval-auc:0.68381	train-auc:0.97721
# [784]	eval-auc:0.68396	train-auc:0.97729
# [785]	eval-auc:0.68407	train-auc:0.97721
# [786]	eval-auc:0.68439	train-auc:0.97702
# [787]	eval-auc:0.68405	train-auc:0.97724
# [788]	eval-auc:0.68420	train-auc:0.97703
# [789]	eval-auc:0.68463	train-auc:0.97707
# [790]	eval-auc:0.68398	train-auc:0.97694
# [791]	eval-auc:0.68375	train-auc:0.97708
# [792]	eval-auc:0.68277	train-auc:0.97740
# [793]	eval-auc:0.68334	train-auc:0.97758
# [794]	eval-auc:0.68273	train-auc:0.97770
# [795]	eval-auc:0.68291	train-auc:0.97756
# [796]	eval-auc:0.68338	train-auc:0.97727
# [797]	eval-auc:0.68268	train-auc:0.97735
# [798]	eval-auc:0.68308	train-auc:0.97743
# [799]	eval-auc:0.68312	train-auc:0.97755
# [800]	eval-auc:0.68154	train-auc:0.97772
# [801]	eval-auc:0.68241	train-auc:0.97785
# [802]	eval-auc:0.68132	train-auc:0.97801
# [803]	eval-auc:0.68152	train-auc:0.97808
# [804]	eval-auc:0.68212	train-auc:0.97818
# [805]	eval-auc:0.68250	train-auc:0.97807
# [806]	eval-auc:0.68246	train-auc:0.97820
# [807]	eval-auc:0.68281	train-auc:0.97829
# [808]	eval-auc:0.68169	train-auc:0.97850
# [809]	eval-auc:0.68165	train-auc:0.97855
# [810]	eval-auc:0.68151	train-auc:0.97863
# [811]	eval-auc:0.68247	train-auc:0.97865
# [812]	eval-auc:0.68189	train-auc:0.97855
# [813]	eval-auc:0.68152	train-auc:0.97854
# [814]	eval-auc:0.68212	train-auc:0.97845
# [815]	eval-auc:0.68140	train-auc:0.97912
# [816]	eval-auc:0.68188	train-auc:0.97908
# [817]	eval-auc:0.68085	train-auc:0.97906
# [818]	eval-auc:0.67981	train-auc:0.97917
# [819]	eval-auc:0.68002	train-auc:0.97894
# [820]	eval-auc:0.68058	train-auc:0.97892
# [821]	eval-auc:0.68127	train-auc:0.97910
# [822]	eval-auc:0.68133	train-auc:0.97922
# [823]	eval-auc:0.68149	train-auc:0.97933
# [824]	eval-auc:0.68164	train-auc:0.97942
# [825]	eval-auc:0.68201	train-auc:0.97952
# [826]	eval-auc:0.68241	train-auc:0.97952
# [827]	eval-auc:0.68280	train-auc:0.97943
# [828]	eval-auc:0.68304	train-auc:0.97952
# [829]	eval-auc:0.68331	train-auc:0.97935
# [830]	eval-auc:0.68332	train-auc:0.97956
# [831]	eval-auc:0.68279	train-auc:0.97955
# [832]	eval-auc:0.68321	train-auc:0.97944
# [833]	eval-auc:0.68308	train-auc:0.97957
# [834]	eval-auc:0.68241	train-auc:0.97984
# [835]	eval-auc:0.68331	train-auc:0.97985
# [836]	eval-auc:0.68276	train-auc:0.97988
# [837]	eval-auc:0.68308	train-auc:0.97977
# [838]	eval-auc:0.68369	train-auc:0.97993
# [839]	eval-auc:0.68469	train-auc:0.98007
# [840]	eval-auc:0.68398	train-auc:0.98033
# [841]	eval-auc:0.68396	train-auc:0.98035
# [842]	eval-auc:0.68373	train-auc:0.98068
# [843]	eval-auc:0.68268	train-auc:0.98064
# [844]	eval-auc:0.68245	train-auc:0.98076
# [845]	eval-auc:0.68215	train-auc:0.98100
# [846]	eval-auc:0.68164	train-auc:0.98094
# [847]	eval-auc:0.68198	train-auc:0.98082
# [848]	eval-auc:0.68173	train-auc:0.98086
# [849]	eval-auc:0.68211	train-auc:0.98063
# [850]	eval-auc:0.68208	train-auc:0.98071
# [851]	eval-auc:0.68264	train-auc:0.98051
# [852]	eval-auc:0.68322	train-auc:0.98047
# [853]	eval-auc:0.68364	train-auc:0.98027
# [854]	eval-auc:0.68245	train-auc:0.98055
# [855]	eval-auc:0.68288	train-auc:0.98071
# [856]	eval-auc:0.68300	train-auc:0.98087
# [857]	eval-auc:0.68310	train-auc:0.98107
# [858]	eval-auc:0.68406	train-auc:0.98116
# [859]	eval-auc:0.68469	train-auc:0.98087
# [860]	eval-auc:0.68381	train-auc:0.98100
# [861]	eval-auc:0.68503	train-auc:0.98096
# [862]	eval-auc:0.68432	train-auc:0.98121
# [863]	eval-auc:0.68469	train-auc:0.98136
# [864]	eval-auc:0.68431	train-auc:0.98143
# [865]	eval-auc:0.68559	train-auc:0.98130
# [866]	eval-auc:0.68622	train-auc:0.98129
# [867]	eval-auc:0.68667	train-auc:0.98124
# [868]	eval-auc:0.68539	train-auc:0.98168
# [869]	eval-auc:0.68572	train-auc:0.98151
# [870]	eval-auc:0.68468	train-auc:0.98173
# [871]	eval-auc:0.68553	train-auc:0.98155
# [872]	eval-auc:0.68436	train-auc:0.98201
# [873]	eval-auc:0.68433	train-auc:0.98213
# [874]	eval-auc:0.68452	train-auc:0.98227
# [875]	eval-auc:0.68522	train-auc:0.98221
# [876]	eval-auc:0.68552	train-auc:0.98218
# [877]	eval-auc:0.68628	train-auc:0.98189
# [878]	eval-auc:0.68599	train-auc:0.98164
# [879]	eval-auc:0.68499	train-auc:0.98223
# [880]	eval-auc:0.68532	train-auc:0.98262
# [881]	eval-auc:0.68515	train-auc:0.98282
# [882]	eval-auc:0.68375	train-auc:0.98289
# [883]	eval-auc:0.68250	train-auc:0.98306
# [884]	eval-auc:0.68219	train-auc:0.98300
# [885]	eval-auc:0.68159	train-auc:0.98310
# [886]	eval-auc:0.68241	train-auc:0.98301
# [887]	eval-auc:0.68180	train-auc:0.98330
# [888]	eval-auc:0.68187	train-auc:0.98329
# [889]	eval-auc:0.68106	train-auc:0.98361
# [890]	eval-auc:0.68056	train-auc:0.98335
# [891]	eval-auc:0.68169	train-auc:0.98322
# [892]	eval-auc:0.68227	train-auc:0.98311
# [893]	eval-auc:0.68272	train-auc:0.98300
# [894]	eval-auc:0.68250	train-auc:0.98290
# [895]	eval-auc:0.68221	train-auc:0.98317
# [896]	eval-auc:0.68215	train-auc:0.98336
# [897]	eval-auc:0.68099	train-auc:0.98368
# [898]	eval-auc:0.68164	train-auc:0.98370
# [899]	eval-auc:0.68141	train-auc:0.98377
# [900]	eval-auc:0.68096	train-auc:0.98408
# [901]	eval-auc:0.68049	train-auc:0.98407
# [902]	eval-auc:0.67954	train-auc:0.98394
# [903]	eval-auc:0.68022	train-auc:0.98372
# [904]	eval-auc:0.67950	train-auc:0.98406
# [905]	eval-auc:0.67927	train-auc:0.98455
# [906]	eval-auc:0.67931	train-auc:0.98473
# [907]	eval-auc:0.67861	train-auc:0.98492
# [908]	eval-auc:0.68032	train-auc:0.98447
# [909]	eval-auc:0.68004	train-auc:0.98453
# [910]	eval-auc:0.68044	train-auc:0.98462
# [911]	eval-auc:0.68086	train-auc:0.98469
# [912]	eval-auc:0.68093	train-auc:0.98465
# [913]	eval-auc:0.68142	train-auc:0.98478
# [914]	eval-auc:0.68065	train-auc:0.98495
# [915]	eval-auc:0.68066	train-auc:0.98496
# [916]	eval-auc:0.68027	train-auc:0.98528
# [917]	eval-auc:0.67975	train-auc:0.98535
# [918]	eval-auc:0.68059	train-auc:0.98531
# [919]	eval-auc:0.68037	train-auc:0.98537
# [920]	eval-auc:0.68144	train-auc:0.98542
# [921]	eval-auc:0.68133	train-auc:0.98548
# [922]	eval-auc:0.68188	train-auc:0.98572
# [923]	eval-auc:0.68206	train-auc:0.98571
# [924]	eval-auc:0.68179	train-auc:0.98557
# [925]	eval-auc:0.68146	train-auc:0.98580
# [926]	eval-auc:0.68068	train-auc:0.98592
# [927]	eval-auc:0.68100	train-auc:0.98588
# [928]	eval-auc:0.68073	train-auc:0.98584
# [929]	eval-auc:0.68110	train-auc:0.98581
# [930]	eval-auc:0.68092	train-auc:0.98589
# [931]	eval-auc:0.68037	train-auc:0.98612
# [932]	eval-auc:0.67999	train-auc:0.98622
# [933]	eval-auc:0.68035	train-auc:0.98618
# [934]	eval-auc:0.68049	train-auc:0.98623
# [935]	eval-auc:0.67903	train-auc:0.98637
# [936]	eval-auc:0.68060	train-auc:0.98603
# [937]	eval-auc:0.67967	train-auc:0.98636
# [938]	eval-auc:0.67882	train-auc:0.98656
# [939]	eval-auc:0.67914	train-auc:0.98673
# [940]	eval-auc:0.67972	train-auc:0.98665
# [941]	eval-auc:0.68008	train-auc:0.98655
# [942]	eval-auc:0.68017	train-auc:0.98659
# [943]	eval-auc:0.67950	train-auc:0.98678
# [944]	eval-auc:0.67991	train-auc:0.98684
# [945]	eval-auc:0.67956	train-auc:0.98676
# [946]	eval-auc:0.67899	train-auc:0.98704
# [947]	eval-auc:0.67872	train-auc:0.98688
# [948]	eval-auc:0.67834	train-auc:0.98692
# [949]	eval-auc:0.67822	train-auc:0.98687
# [950]	eval-auc:0.67903	train-auc:0.98671
# [951]	eval-auc:0.68002	train-auc:0.98668
# [952]	eval-auc:0.67966	train-auc:0.98702
# [953]	eval-auc:0.68017	train-auc:0.98692
# [954]	eval-auc:0.67972	train-auc:0.98694
# [955]	eval-auc:0.67964	train-auc:0.98694
# [956]	eval-auc:0.67930	train-auc:0.98711
# [957]	eval-auc:0.67942	train-auc:0.98710
# [958]	eval-auc:0.67900	train-auc:0.98708
# [959]	eval-auc:0.67861	train-auc:0.98723
# [960]	eval-auc:0.67893	train-auc:0.98719
# [961]	eval-auc:0.67916	train-auc:0.98727
# [962]	eval-auc:0.68021	train-auc:0.98717
# [963]	eval-auc:0.68021	train-auc:0.98737
# [964]	eval-auc:0.68016	train-auc:0.98735
# [965]	eval-auc:0.68072	train-auc:0.98743
# [966]	eval-auc:0.68081	train-auc:0.98749
# [967]	eval-auc:0.68122	train-auc:0.98780
#   0%|          | 0/250 [00:04<?, ?trial/s, best loss=?]
# job exception: `best_iteration` is only defined when early stopping is used.
#   0%|          | 0/250 [00:04<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 61
#      55     best = fmin(score, space, algo=tpe.suggest,
#      56                 trials=trials,
#      57                 max_evals=250)
#      58     return best
# ---> 61 best_hyperparams = optimize(
#      62                             Trials()
#      63                             )
#      64 print("The best hyperparameters are: ", "\n")
#      65 print(best_hyperparams)
#
# Cell In[13], line 55, in optimize(trials, random_state)
#      34 space = {
#      35     'n_estimators': hp.quniform('n_estimators', 100, 1000, 1),
#      36     'eta': hp.quniform('eta', 0.025, 0.5, 0.025),
#    (...)
#      52     'seed': random_state
#      53 }
#      54 # Use the fmin function from Hyperopt to find the best hyperparameters
# ---> 55 best = fmin(score, space, algo=tpe.suggest,
#      56             trials=trials,
#      57             max_evals=250)
#      58 return best
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/py38/lib/python3.8/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/py38/lib/python3.8/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/py38/lib/python3.8/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/py38/lib/python3.8/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/py38/lib/python3.8/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/py38/lib/python3.8/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/py38/lib/python3.8/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[13], line 13, in score(params)
#       8 watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
#       9 gbm_model = xgb.train(params, dtrain, num_round,
#      10                       evals=watchlist,
#      11                       verbose_eval=True)
#      12 predictions = gbm_model.predict(dvalid,
# ---> 13                                 ntree_limit=gbm_model.best_iteration + 1)
#      14 score = roc_auc_score(df_test_y, predictions)
#      15 # TODO: Add the importance for the selected features
#      16 #print(gbm_model.feature_importances_)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/py38/lib/python3.8/site-packages/xgboost/core.py:2709, in Booster.best_iteration(self)
#    2706 if best is not None:
#    2707     return int(best)
# -> 2709 raise AttributeError(
#    2710     "`best_iteration` is only defined when early stopping is used."
#    2711 )
#
# AttributeError: `best_iteration` is only defined when early stopping is used.

# %%
# train the best model
best_params = best_hyperparams
best_params.update({'eval_metric': 'auc'})

model = XGBClassifier(silent=True)
model.set_params(**best_params)
dtrain = xgb.DMatrix(df_train_X, label=df_train_y)
dvalid = xgb.DMatrix(df_test_X, label=df_test_y)
watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
model = xgb.train(best_params, dtrain, 
                  evals=watchlist, 
                  verbose_eval=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # train the best model
# ----> 2 best_params = best_hyperparams
#       3 best_params.update({'eval_metric': 'auc'})
#       5 model = XGBClassifier(silent=True)
#
# NameError: name 'best_hyperparams' is not defined

# %% [markdown]
# ### Check model performance on test set

# %%
# calculate model performance

test_set_prediction = model.predict(xgb.DMatrix(df_test_X))
foo1 = pd.DataFrame({'predict': test_set_prediction}, index=df_test_X.index)
df_test.loc[:, 'predict'] = foo1['predict']
df_test.sort_values('predict', ascending=False, inplace=True)

# 10% of the popultion is selected for target campaigns
p= 0.1
df_test.loc[:, 'predict_label'] = 0
cutoff_val = df_test.iloc[int(p*len(df_test)), ]['predict']
df_test.loc[df_test.predict>= cutoff_val, 'predict_label'] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # calculate model performance
# ----> 3 test_set_prediction = model.predict(xgb.DMatrix(df_test_X))
#       4 foo1 = pd.DataFrame({'predict': test_set_prediction}, index=df_test_X.index)
#       5 df_test.loc[:, 'predict'] = foo1['predict']
#
# NameError: name 'model' is not defined

# %%
df_test.predict_label.value_counts().sort_index()
# Out:
# 0    1714
# 1     191
# Name: predict_label, dtype: int64

# %%
a = confusion_matrix(
    df_test['product02'],
    df_test['predict_label'],
    labels = [0, 1])

print(a)

print('\n\n')
actual_postive = len(df_test.loc[df_test.loc[:, 'product02'] == 1, :])
total_num = len(df_test)
predicted_and_actual_postive = len(df_test.loc[
    (df_test.loc[:, 'product02'] == 1)
    &
    (df_test.loc[:, 'predict_label']), :])
predicted_postive = sum(df_test['predict_label'])
model_lift = (predicted_and_actual_postive / predicted_postive) / (actual_postive / total_num)

print(f"{actual_postive} positives out of total {total_num} customers, which is " +
                    f"{ (100 * (actual_postive) / total_num):.02f} %")
print(f"{predicted_and_actual_postive} actual positives out of total {predicted_postive} " +
                    "predicted positives, which is " +
                    f"{ (100 * (predicted_and_actual_postive) / predicted_postive):.02f} %")
print(f"MODEL LIFT = {model_lift:.03f}")

print(f"Precision: { (100 * predicted_and_actual_postive / predicted_postive):.02f} %")
print(f"Recall   : { (100 * predicted_and_actual_postive / actual_postive):.02f} %")

print(f"By contacting {(100 * predicted_postive / total_num):.02f} % of the base, you hit " +
                    f"{(100 * predicted_and_actual_postive / actual_postive):.02f} % of your target group")
# Out:
# [[1099   25]
#  [ 615  166]]
#
#
#
# 781 positives out of total 1905 customers, which is 41.00 %
# 166 actual positives out of total 191 predicted positives, which is 86.91 %
# MODEL LIFT = 2.120
# Precision: 86.91 %
# Recall   : 21.25 %
# By contacting 10.03 % of the base, you hit 21.25 % of your target group

# %%
# save model
model.save_model("best_model_xgb.json")

# %%
# save shaply plot for model explanation
explainer = shap.TreeExplainer(model)
shap_values = explainer(df_test_X)
shap.summary_plot(shap_values, df_test_X, show=False)
plt.savefig('shap_plot.png', dpi=200, bbox_inches='tight')
plt.close()

# %% [markdown]
# ### Use the saved model to do scoring

# %%
# load the scoring data
df_test = pd.read_csv('telecom_test.csv')

# Prepare the scoring data
# fill missing values
df_test[['gender', 'house_type']]= df_test[['gender', 'house_type']].fillna(value='missing')
df_test['income'] = df_test['income'].fillna((df_test['income'].mean()))
df_test['var1'] = df_test['var1'].fillna((df_test['var1'].mean()))
df_test['age'] = df_test['age'].fillna((df_test['age'].mean()))

# log transformation
df_test['income'] = np.log(df_test['income'])

# feature engineering
def calculate_duration(lastVisit):
    if lastVisit:
      lastVisit = datetime.strptime(lastVisit, "%m/%d/%Y %H:%M").date()
      today = date.today()
      return (today - lastVisit).days
    else:
      return 0

df_test['duration'] = df_test['lastVisit'].apply(calculate_duration)
df_test = df_test.drop(['lastVisit'], axis=1)

df_test_onehot = pd.get_dummies(df_test, dummy_na=True)
df_test_onehot = df_test_onehot.drop(['subscriber'], axis=1)

# load the saved model and use it to predict
dtest = xgb.DMatrix(df_test_onehot)
model_xgb_pred = xgb.Booster()
model_xgb_pred.load_model("best_model_xgb.json")
print(model_xgb_pred)
scores = model_xgb_pred.predict(dtest)
# Out:
# <xgboost.core.Booster object at 0x7f294c355750>

# %%
# save the output in csv
df_test['score'] = scores
output = df_test[['subscriber', 'score']]
output.to_csv('output.csv', index=False)
